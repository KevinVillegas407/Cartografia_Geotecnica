# %% [markdown]
# ## Método Heurístico

# %% [markdown]
# Importamos nuestras variables y creamos el DataFrame

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import rasterio as rio
import seaborn as sns
import statsmodels.graphics.api as smg
import warnings
warnings.filterwarnings("ignore")

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_4%20-%20Inventario%20de%20eventos/InventarioRaster/tif1.tif?raw=true')
inventario=raster.read(1)
inventario=np.where(inventario == 65535,0,1)
plt.imshow(inventario)
plt.colorbar();

print('Forma: ', inventario.shape)
print('Valores únicos: ', np.unique(inventario))
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [0 1]

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_3%20-%20Informaci%C3%B3n%20secundaria/Pendientes/slope.tif?raw=true')
msk=raster.read_masks(1)
msk=np.where(msk==0,np.nan,1)
plt.imshow(msk)
plt.colorbar();

print('Forma: ', msk.shape)
print('Valores únicos: ', np.unique(msk))
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [ 1. nan]

# %%
inventario1=msk*inventario
inventario1=np.where(inventario1==255,1,inventario1)
plt.imshow(inventario1)
plt.colorbar();

print('Forma: ', inventario1.shape)
print('Valores únicos: ', np.unique(inventario1))
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [ 0.  1. nan]

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_3%20-%20Informaci%C3%B3n%20secundaria/Pendientes/slope.tif?raw=true')
slope=raster.read(1)
slope=np.where(slope<0,np.nan,slope)
plt.imshow(slope)
plt.colorbar();

print('Forma: ', slope.shape)
print('Valores únicos: ', np.unique(slope))
type(slope)
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [0.0000000e+00 5.0321757e-04 5.0324190e-04 ... 7.6529427e+01 7.7654839e+01
#            nan]
# numpy.ndarray

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_3%20-%20Informaci%C3%B3n%20secundaria/Aspectos/asp2.tif?raw=true')
aspecto=raster.read(1)
#aspecto=np.where(aspecto<-100,np.nan,aspecto)
aspecto=np.where(aspecto == aspecto.min(), np.nan, aspecto)
plt.imshow(aspecto)
plt.colorbar()

print('Forma: ', aspecto.shape)
print('Valores únicos: ', np.unique(aspecto))
type(aspecto)
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [-1.0000000e+00  0.0000000e+00  7.9856243e-04 ...  3.5999899e+02
#   3.5999973e+02            nan]
# numpy.ndarray

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_3%20-%20Informaci%C3%B3n%20secundaria/Curvatura2/curv2.tif?raw=true')
curvatura=raster.read(1)
curvatura=np.where(curvatura == curvatura.min(), np.nan, curvatura)
plt.imshow(curvatura)
plt.colorbar()

print('Forma: ', curvatura.shape)
print('Valores únicos: ', np.unique(curvatura))
type(curvatura)
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [-112.85254   -96.634766  -91.16406  ...   96.68652   100.80762
#          nan]
# numpy.ndarray

# %%
curvatura1 = msk*curvatura
plt.imshow(curvatura1)
plt.colorbar();

print('Forma: ', curvatura1.shape)
print('Valores únicos: ', np.unique(curvatura1))
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [-112.85253906  -96.63476562  -91.1640625  ...   96.68652344  100.80761719
#            nan]

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_3%20-%20Informaci%C3%B3n%20secundaria/FlujoAcumulado/flowaccum.tif?raw=true')
flujo=raster.read(1)
flujo=np.where(flujo == flujo.min(), np.nan, flujo)
#flujo=np.where(flujo>50,0,flujo)
plt.imshow(flujo)
plt.colorbar()

print('Forma: ', flujo.shape)
print('Valores únicos: ', np.unique(flujo))
type(flujo)
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [0.00000e+00 1.00000e+00 2.00000e+00 ... 4.49906e+05 4.49913e+05
#          nan]
# numpy.ndarray

# %%
flujo1 = msk*flujo
plt.imshow(flujo1)
plt.colorbar();

print('Forma: ', flujo1.shape)
print('Valores únicos: ', np.unique(flujo1))
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [0.00000e+00 1.00000e+00 2.00000e+00 ... 4.49833e+05 4.49906e+05
#          nan]

# %%
raster = rio.open('https://github.com/KevinVillegas407/Cartografia_Geotecnica/blob/main/Taller_3%20-%20Informaci%C3%B3n%20secundaria/Elevacion/Elevaci%C3%B3n1.tif?raw=true')
elevacion=raster.read(1)
elevacion=np.where(elevacion==0,np.nan,elevacion)
plt.imshow(elevacion)
plt.colorbar();

print('Forma: ', elevacion.shape)
print('Valores únicos: ', np.unique(elevacion))
type(elevacion)
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [1729.6    1729.64   1729.94   ... 2624.2852 2625.           nan]
# numpy.ndarray

# %%
elevacion1 = msk*elevacion
plt.imshow(elevacion1)
plt.colorbar();

print('Forma: ', elevacion1.shape)
print('Valores únicos: ', np.unique(elevacion1))
# Out:
# Forma:  (1108, 948)
# Valores únicos:  [1729.93994141 1729.95996094 1730.         ... 2624.19677734 2625.
#            nan]

# %%
#Convertimos matrices a vectores

inventariovector = inventario1.ravel()
print('Longitud inventariovector: ', inventariovector.shape[0])

slopevector = slope.ravel()
print('Longitud slopevector: ', slopevector.shape[0])

aspectovector = aspecto.ravel()
print('Longitud aspectovector: ', aspectovector.shape[0])

curvaturavector = curvatura1.ravel()
print('Longitud curvaturavector: ', curvaturavector.shape[0])

flujovector = flujo1.ravel()
print('Longitud flujovector: ', flujovector.shape[0])

elevacionvector = elevacion1.ravel()
print('Longitud elevacionvector: ', elevacionvector.shape[0])
# Out:
# Longitud inventariovector:  1050384
# Longitud slopevector:  1050384
# Longitud aspectovector:  1050384
# Longitud curvaturavector:  1050384
# Longitud flujovector:  1050384
# Longitud elevacionvector:  1050384

# %%
#eliminamos los nans del vector

inventariovectorMenM = inventariovector[~np.isnan(inventariovector)]
print('Longitud inventariovectorMenM: ', inventariovectorMenM.shape[0])

slopevectorMenM = slopevector[~np.isnan(slopevector)]
print('Longitud slopevectorMenM: ', slopevectorMenM.shape[0])

aspectovectorMenM = aspectovector[~np.isnan(aspectovector)]
print('Longitud aspectovectorMenM: ', aspectovectorMenM.shape[0])

curvaturavectorMenM = curvaturavector[~np.isnan(curvaturavector)]
print('Longitud curvaturavectorMenM: ', curvaturavectorMenM.shape[0])

flujovectorMenM = flujovector[~np.isnan(flujovector)]
print('Longitud flujovectorMenM: ', flujovectorMenM.shape[0])

elevacionvectorMenM = elevacionvector[~np.isnan(elevacionvector)]
print('Longitud elevacionvectorMenM: ', elevacionvectorMenM.shape[0])
# Out:
# Longitud inventariovectorMenM:  448299
# Longitud slopevectorMenM:  448299
# Longitud aspectovectorMenM:  448299
# Longitud curvaturavectorMenM:  448299
# Longitud flujovectorMenM:  448299
# Longitud elevacionvectorMenM:  448299

# %%
#Realizamos el Dataframe

diccionario={'inventario':inventariovectorMenM, 'pendiente':slopevectorMenM, 'aspectos':aspectovectorMenM, 
             'curvatura':curvaturavectorMenM, 'Flujo Acumulado': flujovectorMenM, 'elevacion':elevacionvectorMenM}

df=pd.DataFrame(diccionario)
print(list(df.columns))

#tablaDatos.tail(5)
# Out:
# ['inventario', 'pendiente', 'aspectos', 'curvatura', 'Flujo Acumulado', 'elevacion']

# %%
df.head()
# Out:
#    inventario  pendiente    aspectos  curvatura  Flujo Acumulado    elevacion
# 0         0.0   0.757180  224.523972   0.260742              1.0  2609.993896
# 1         0.0  13.868361  169.804703  12.146484              0.0  2610.000000
# 2         0.0  14.844854  183.360001   7.830078              5.0  2609.767822
# 3         0.0  11.791483  195.952194   8.045898              1.0  2609.930908
# 4         0.0   6.822078  204.412933   4.381836              0.0  2610.000000

# %% [markdown]
# Después de haber realizado esto, podemos comenzar con el método

# %% [markdown]
# **Método de análisis jerárquico de procesos APH**

# %% [markdown]
# Creamos la matriz de igualdad en la escala de Saaty para encontrar el vector propio que corresponde al máximo valor propio, normalizar y hallar los pesos de cada variable

# %%
A = ([[  1, 3, 1/7, 1/5,   1, 1/3, 1],
      [1/3, 1, 1/7, 1/7, 1/3, 1/3, 1],
      [  7, 7,   1,   1,   1,   3, 7],
      [  5, 7,   1,   1,   3,   3, 5],
      [  1, 3,   1, 1/3,   1, 1/3, 1],
      [  3, 3, 1/3, 1/3,   3,   1, 7],
      [  1, 1, 1/7, 1/5,   1, 1/7, 1]])

B = np.array(A) # para transformarla en una matriz

valores, vectores = np.linalg.eig(B) # Función para calcular los valores y vectores propios

vector_norm = vectores/np.linalg.norm(vectores, ord=1) # normalización de los vectores

print('Estos son los valores propios:\n',valores)
print('\nEstos son los vectores propios:\n', vectores)
print('\nEsto son los vectores propios normalizados:\n',vector_norm)
# Out:
# Estos son los valores propios:
#  [ 7.63718313+0.j         -0.19089618+1.92305777j -0.19089618-1.92305777j
#  -0.02397119+0.87613592j -0.02397119-0.87613592j -0.1037242 +0.49527008j
#  -0.1037242 -0.49527008j]
#
# Estos son los vectores propios:
#  [[ 0.13478244+0.j         -0.07766513+0.01218809j -0.07766513-0.01218809j
#   -0.12608108+0.2406179j  -0.12608108-0.2406179j   0.01353762+0.03961628j
#    0.01353762-0.03961628j]
#  [ 0.07884071+0.j          0.04423256-0.01112249j  0.04423256+0.01112249j
#   -0.09475648-0.05158954j -0.09475648+0.05158954j -0.00576767+0.0394081j
#   -0.00576767-0.0394081j ]
#  [ 0.62860504+0.j          0.73714735+0.j          0.73714735-0.j
#    0.46782997+0.21648453j  0.46782997-0.21648453j  0.23451501+0.05805825j
#    0.23451501-0.05805825j]
#  [ 0.62243901+0.j          0.31329977-0.03096731j  0.31329977+0.03096731j
#   -0.55892381+0.j         -0.55892381-0.j         -0.87561846+0.j
#   -0.87561846-0.j        ]
# ...

# %%
CI = (valores[0] - len(valores)) / (len(valores) - 1)

CR = CI / 1.32

if CR < 0.1:    print('La designación de datos fue aceptable:\n', CR)
else:
    print('La designación de datos NO fue aceptable:\n', CR)
# Out:
# La designación de datos fue aceptable:
#  (0.08045241593263748+0j)

# %% [markdown]
# Continuando utilizamos el mayor vector propio (El de la posición 0), el cuál nos indica los pesos de las variables utilizadas

# %%
matrizIndices = ['pendiente', 'aspectos', 'curvatura', 'Flujo Acumulado', 'elevacion']
pesoVariables = vector_norm[:,0]
#print(pesoVariables)

for i in range(len(matrizIndices)):
    print(f'{matrizIndices[i]}:', pesoVariables[i])
# Out:
# pendiente: (0.05927837617095113+0j)
# aspectos: (0.03467476305127935+0j)
# curvatura: (0.2764654336469559+0j)
# Flujo Acumulado: (0.2737535663357602+0j)
# elevacion: (0.09508619201141212+0j)

# %% [markdown]
# **Método de asignación directa**

# %% [markdown]
# Para este método, debemos elegir qué valores utilizar en cada clase. Este procedimiento lo realizamos a continuación:

# %%
nombresColumnas = ['pendiente', 'aspectos', 'curvatura', 'Flujo Acumulado', 'elevacion']
nombresBonitos = ['Pendientes', 'Aspectos', 'Curvatura', 'Flujo acumulado', 'Elevación']

# %%
pendienteReclass = np.where ( (np.logical_and (slope >= 0, slope < 9 )), 0.1, slope );
pendienteReclass = np.where ( (np.logical_and (pendienteReclass >= 9, pendienteReclass < 19)), 0.4, pendienteReclass);
pendienteReclass = np.where ( (np.logical_and (pendienteReclass >= 19, pendienteReclass < 28 )), 0.7, pendienteReclass);
pendienteReclass = np.where ( (np.logical_and (pendienteReclass >= 28, pendienteReclass < 48 )), 1, pendienteReclass);
pendienteReclass = np.where ( pendienteReclass >= 48, 0.8, pendienteReclass);

#plt.figure(figsize=(40, 10))  # Ajusta el tamaño
plt.imshow(pendienteReclass)
#plt.savefig('MHeuristico_PendienteReclasificado.png', dpi=500, bbox_inches='tight')
plt.colorbar();

print('Pendientes Reclasificadas')
print('Forma: ', pendienteReclass.shape)
print('Valores únicos: ', np.unique(pendienteReclass))
# Out:
# Pendientes Reclasificadas
# Forma:  (1108, 948)
# Valores únicos:  [0.1 0.4 0.7 0.8 1.  nan]

# %%
tablaDatosSinInv = df.drop('inventario', axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
from scipy.stats import gaussian_kde

# Genera datos de muestra
data = tablaDatosSinInv['pendiente']

# Estima la densidad utilizando la función gaussian_kde
kde = gaussian_kde(data)

# Evalúa la densidad en un rango de valores
x_values = np.linspace(data.min(), data.max(), 1000)
density = kde(x_values)

# Encuentra los picos en la función de densidad
peaks, _ = find_peaks(density)

# Dibuja la función de densidad
plt.plot(x_values, density, color='blue', label='Densidad')

# Marca los picos en el gráfico de densidad
plt.plot(x_values[peaks], density[peaks], "ro", label="Quiebres Naturales")

# Muestra el gráfico completo
plt.legend()
plt.show()

# Muestra los valores de los quiebres naturales en el eje x
peak_values = x_values[peaks]
print("Valores de los quiebres naturales en el eje x:")
print(peak_values)
# Out:
# Valores de los quiebres naturales en el eje x:
# [27.28413247]

# %% [markdown]
# Utilizamos estos Natural breaks para elegir los rangos en las reclasificaciones anteriores

# %%
aspectoReclass = np.where ( aspecto < 125, 0.1, aspecto);
aspectoReclass = np.where ( (np.logical_and (aspectoReclass >= 125, aspectoReclass < 230)), 1, aspectoReclass)
aspectoReclass = np.where ( aspectoReclass >= 230, 0.4, aspectoReclass);

#plt.figure(figsize=(40, 10))  # Ajusta el tamaño
plt.imshow(aspectoReclass)

#plt.savefig('MHeuristico_AspectoReclasificado.png', dpi=500, bbox_inches='tight')
plt.colorbar();

print('Aspecto Reclasificadas')
print('Forma: ', aspectoReclass.shape)
print('Valores únicos: ', np.unique(aspectoReclass))
# Out:
# Aspecto Reclasificadas
# Forma:  (1108, 948)
# Valores únicos:  [0.1 0.4 1.  nan]

# %%
p40 = np.nanpercentile(curvatura1, 40)
p60 = np.nanpercentile(curvatura1, 60)

curvaturaReclass = np.where ( (np.logical_and (curvatura1 > p40, curvatura1 <  p60)), 0.4, curvatura1)
curvaturaReclass = np.where(curvaturaReclass >=  p60, 1, curvaturaReclass)
curvaturaReclass = np.where(curvaturaReclass <= p40, 0.2, curvaturaReclass)

#plt.figure(figsize=(40, 10))  # Ajusta el tamaño
plt.imshow(curvaturaReclass)

#plt.savefig('MHeuristico_CurvaturaReclasificado.png', dpi=500, bbox_inches='tight')
plt.colorbar();

print('Curvatura Reclass')
print('Forma: ', curvaturaReclass.shape)
print('Valores únicos: ', np.unique(curvaturaReclass))
# Out:
# Curvatura Reclass
# Forma:  (1108, 948)
# Valores únicos:  [0.2 0.4 1.  nan]

# %%
flujoAcumReclass = np.where ( flujo1 < 100, 0.6, flujo1)
flujoAcumReclass = np.where ( (np.logical_and (flujoAcumReclass >= 100, flujoAcumReclass < 6000)), 0.2, flujoAcumReclass)
flujoAcumReclass = np.where ( flujoAcumReclass > 6000, 0.4, flujoAcumReclass);


#plt.figure(figsize=(40, 10))  # Ajusta el tamaño
plt.imshow(flujoAcumReclass)

#plt.savefig('MHeuristico_FlujoAcumReclasificado.png', dpi=500, bbox_inches='tight')
plt.colorbar();

print('Flujo Acumulado Reclasificadas')
print('Forma: ', flujoAcumReclass.shape)
print('Valores únicos: ', np.unique(flujoAcumReclass))
# Out:
# Flujo Acumulado Reclasificadas
# Forma:  (1108, 948)
# Valores únicos:  [0.2 0.4 0.6 nan]

# %%
#elevacionReclass = np.where ( elevacion1 < 100, 0.3, elevacion1)
elevacionReclass = np.where ( elevacion1 < 700, 0.1, elevacion1)
elevacionReclass = np.where ( (np.logical_and (elevacionReclass >= 700, elevacionReclass < 1000)), 0.4, elevacionReclass)
elevacionReclass = np.where ( (np.logical_and (elevacionReclass >= 1000, elevacionReclass < 1700)), 0.9, elevacionReclass)
elevacionReclass = np.where ( (np.logical_and (elevacionReclass >= 1700, elevacionReclass < 2100)), 0.2, elevacionReclass)
elevacionReclass = np.where ( (np.logical_and (elevacionReclass >= 2100, elevacionReclass < 2550)), 0.7, elevacionReclass)
elevacionReclass = np.where ( elevacionReclass >= 2550, 0.1, elevacionReclass)



#altitudReclass = np.where ( flujoAcumReclass > 6000, 0.1, flujoAcumReclass);


#plt.figure(figsize=(40, 10))  # Ajusta el tamaño
plt.imshow(elevacionReclass)

#plt.savefig('MHeuristico_AltitudReclasificado.png', dpi=500, bbox_inches='tight')
plt.colorbar();

print('Elevacion Reclasificada')
print('Forma: ', elevacionReclass.shape)
print('Valores únicos: ', np.unique(elevacionReclass))
# Out:
# Elevacion Reclasificada
# Forma:  (1108, 948)
# Valores únicos:  [0.1 0.2 0.7 nan]

# %%
for i in range(len(matrizIndices)):
    print(f'{matrizIndices[i]}:', pesoVariables[i])
# Out:
# pendiente: (0.05927837617095113+0j)
# aspectos: (0.03467476305127935+0j)
# curvatura: (0.2764654336469559+0j)
# Flujo Acumulado: (0.2737535663357602+0j)
# elevacion: (0.09508619201141212+0j)

# %%
for i in range(len(matrizIndices)):
    print(f'{matrizIndices[i]}:', pesoVariables[i].real)
# Out:
# pendiente: 0.05927837617095113
# aspectos: 0.03467476305127935
# curvatura: 0.2764654336469559
# Flujo Acumulado: 0.2737535663357602
# elevacion: 0.09508619201141212

# %%
clasesPeso = [pendienteReclass, curvaturaReclass, aspectoReclass, flujoAcumReclass, elevacionReclass]
IS = (pesoVariables[0].real * clasesPeso[0]) + (pesoVariables[1].real * clasesPeso[1]) + (pesoVariables[2].real * clasesPeso[2]) + (pesoVariables[3].real * clasesPeso[3]) + (pesoVariables[4].real * clasesPeso[4])

#plt.figure(figsize=(40, 10))  # Ajusta el tamaño
plt.imshow(IS)
plt.colorbar()
plt.savefig('MapaHeuristico_Susceptilidad.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# Este sería nuestro mapa de susceptibilidad utilizando el Método Heurístico o Método Criterio de experto

# %% [markdown]
# Ahora hagamos la evaluación del modelo

# %%
inventarioZonaVc = inventario1.ravel()
inventarioVcMenM2 = inventarioZonaVc[~np.isnan(inventarioZonaVc)]

IS_HEU_Vc = IS.ravel()
IS_HEU_VcMenM2 = IS_HEU_Vc[~np.isnan(IS_HEU_Vc)]

print('Longitud inventarioVcMenM2: ', inventariovectorMenM.shape[0])
print('Longitud IS_HEU_VcMenM2: ', IS_HEU_VcMenM2.shape[0], '\n')

#-------------------------------------------

y_real = inventarioVcMenM2
y_IS_HEU = IS_HEU_VcMenM2

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Ajustar el umbral según sea necesario
umbral = (np.nanmin(IS) + np.nanmax(IS))/2
print('Umbral para clasificar como 1:', umbral, '\n')
y_pred = (IS_HEU_VcMenM2 > umbral).astype(int)

# Calcular métricas de evaluación para cada clase
### NOTA: luego del y_real se puede poner la predicción binario o el IS_HEU_VcMenM2 original

from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_real, y_pred)

from sklearn.metrics import classification_report
print(classification_report(y_real, y_pred))
# Out:
# Longitud inventarioVcMenM2:  448299
# Longitud IS_HEU_VcMenM2:  448299
#
# Umbral para clasificar como 1: 0.3577541734689952
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.46      0.63    443207
#          1.0       0.01      0.59      0.02      5092
#
#     accuracy                           0.46    448299
#    macro avg       0.50      0.53      0.33    448299
# weighted avg       0.98      0.46      0.62    448299

# %%
from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(y_real, y_IS_HEU)
plt.plot(fpr,tpr,color='r')
xb = [i*0.01 for i in range(100)]
yb = [i*0.01 for i in range(100)]

plt.plot(xb, yb, linestyle = '--', color = 'b')
plt.grid(True)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curve - Heuristico')
auc = str(round(metrics.auc(fpr,tpr),4))
plt.text(x = 0.7, y = 0.1, s = 'AUC=' + auc + '%', size = 12)
# Out:
# Text(0.7, 0.1, 'AUC=0.5185%')
